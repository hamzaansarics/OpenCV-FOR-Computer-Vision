# %%
import numpy as np
import cv2,random,time
import matplotlib.pyplot as plt
img=cv2.imread('D:\\5.1.12.tiff')
# img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# eimg=cv2.Laplacian(img,-1,ksize=29,scale=11,delta=0,borderType=cv2.BORDER_DEFAULT)
# eimgx=cv2.Sobel(img,-1,dx=1,dy=0,ksize=9,borderType=cv2.BORDER_DEFAULT)
# eimgy=cv2.Sobel(img,-1,dx=0,dy=1,ksize=11,borderType=cv2.BORDER_DEFAULT)
# eimg=cv2.Scharr(img,-2,dx=0,dy=1,borderType=cv2.BORDER_DEFAULT)

plt.imshow(img)
plt.show()
