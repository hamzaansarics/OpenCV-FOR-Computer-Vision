# %%
import cv2
import matplotlib.pyplot as plt
img1=cv2.imread('D:\\jungle.tiff')
img2=cv2.imread('D:\\liquid.tiff')
img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)
images=[img1,img2]
plt.imshow(img2-255)
plt.show()
plt.imshow(img2)
plt.show()
