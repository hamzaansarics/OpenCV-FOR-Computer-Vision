# %%
import cv2,random
import numpy as np
import matplotlib.pyplot as plt
img=cv2.imread('D:\\girl.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#---------High Pass Filters--------------#
# sobelx=cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
# plt.imshow(sobelx)
# plt.show()
#------------Noised Images vid Median Filter---------#
# kernel_image=np.zeros((img.shape),np.uint8)
# p=0.05
# rows,colums,channels=img.shape
# for r in range(rows):
#     for c in range(colums):
#         rndom=random.random()
#         if rndom<p/2:
#             kernel_image[r][c]=[0,0,0]
#         elif rndom<p:
#             kernel_image[r][c]=[255,255,255]
#         else:
#             kernel_image[r][c]=img[r][c]
# nimg=cv2.medianBlur(kernel_image,3)
# plt.imshow(nimg)
# plt.show()
#-------------------Histogram-------------#
# hist=cv2.calcHist([img],[0],None,[255],[0,255])
# hist=plt.hist(img.ravel(),256,[0,256])
# plt.plot(hist)
# plt.show()
#-------------Rotation--------------#
# cam=cv2.VideoCapture(0)
# inc=0
# n=0
# while True:
#     n+=0.1
#     print(n)
#     if n==0.9 or n<1:
#         n=0
#     inc+=1
#     ret,frame=cam.read()
#     rows,colums,channels=frame.shape
#     R=cv2.getRotationMatrix2D((rows,colums),1,n)
#     ot=cv2.warpAffine(frame,R,(rows,colums))
#     cv2.imshow('Recording Video',ot)
#     if cv2.waitKey(1)==27:
#         break
# cv2.destroyAllWindows()
# cam.release()
#-----------Video Writer----------#
# cam=cv2.VideoCapture(0)
# path='D:\\VideoSaver\\new_video2.mp4'
# print(cam.get(3))
# print(cam.get(4))
# rsl=(640,480)
# fr=26
# codec=cv2.VideoWriter_fourcc('X','V','I','D')
# vo=cv2.VideoWriter(path,codec,fr,rsl)
# while True:
#     ret,frame=cam.read()
#     vo.write(frame)
#     cv2.imshow('Recording Video',frame)
#     if cv2.waitKey(1)==27:
#         break
# cv2.destroyAllWindows()
# vo.release()
# cam.release()
#-------Kernel & Convolution--------#
# ker=np.array(([11,11,11],[11,11,11],[11,11,11]),np.float32)/121
# blur=cv2.filter2D(img,-1,ker)
# plt.imshow(blur,cmap='gray')
# plt.show()
#-------Thresholding & Adaptive Thresholding-------#
# gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# ret,th=cv2.threshold(gray,10,255,cv2.THRESH_TOZERO_INV)
# plt.imshow(th,cmap='gray')
# plt.show()
#-----------Ellipse---------#
# elps=cv2.ellipse(img,(100,200),(20,20),0,0,360,(0,255,0),5)
# plt.imshow(elps)
# plt.show()
#--------Max Color  Filter-------#
# img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# R,G,B=cv2.split(img)
# M=np.maximum(np.maximum(R,G),B)
# R[R<M]=0
# G[G<M]=0
# B[B<M]=0
# ot=cv2.merge((R,G,B))
# plt.imshow(ot)
# plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
